# %% [markdown]
# ### Data Science and Machine Learning Toolkit
# #### By: Sebastián Medina Jiménez
# https://www.linkedin.com/in/sebasmedina/
# #### 0. Introduction
#
#
#
#
#
# # Why Jupyter Notebooks?
#
#
# Jupyter notebooks are the best storytelling method in data science due to their seamless integration of code, visualizations, and narrative text. By combining interactive code cells, explanatory text, and data visualizations, Jupyter notebooks enable data scientists to present their analyses and insights in a concise and engaging manner.
#
# # What are the best tools, languages or libraries that every data scientis should know?
# * SQL
# * Pandas
# * A plotting library, should be: seaborn, matplotlib, Plotly
# * Sklearn
# * Tensorflow or pytorch
# * Python Basics like handling with arrays, dictionaries, loops ...
#
# ## Here is an example with one of the most used datasets
# First get the dataset

# %%
from sklearn.datasets import load_iris
import pandas as pd

# Load the Iris dataset
iris = load_iris()

# Access the data and target variables
X = iris.data  # Features (input variables)
y = iris.target  # Target variable (output variable)

# %% [markdown]
# We can do plots

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Select the first three features of the Iris dataset
X_subset = X[:, :3]

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the data points
ax.scatter(X_subset[:, 0], X_subset[:, 1], X_subset[:, 2], c=y)

# Set labels for the axes
ax.set_xlabel('Sepal Length')
ax.set_ylabel('Sepal Width')
ax.set_zlabel('Petal Length')

# Show the plot
plt.show()

# %% [markdown]
# Also we can can calculate what we want!

# %%
# Create a DataFrame with the data and target variables
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['Species'] = iris.target_names[iris.target]

# Group the data by species and describe each group
description = df.groupby('Species').describe()

# Set the display options
pd.options.display.max_columns = None

description
# Out:
#            sepal length (cm)                                              \
#                        count   mean       std  min    25%  50%  75%  max
# Species
# setosa                  50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# versicolor              50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# virginica               50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#            sepal width (cm)                                                \
#                       count   mean       std  min    25%  50%    75%  max
# Species
# setosa                 50.0  3.428  0.379064  2.3  3.200  3.4  3.675  4.4
# versicolor             50.0  2.770  0.313798  2.0  2.525  2.8  3.000  3.4
# virginica              50.0  2.974  0.322497  2.2  2.800  3.0  3.175  3.8
#
#            petal length (cm)                                               \
#                        count   mean       std  min  25%   50%    75%  max
# Species
# ...

# %% [markdown]
# We can do a lot!
# Let's start!!!
